# %%
import cv2 
import numpy as np  
import matplotlib.pyplot as plt 

image_path = "C:/Users/DELL/OneDrive/Desktop/Afraa/Images/T-Rex roaring.jpeg" 
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) 

if image is None: 
    raise FileNotFoundError(f"Image not found: {image_path}")  
    
blurred = cv2.GaussianBlur(image, (5, 5), 1.4)
roberts_x = np.array([[1, 0], [0, -1]], dtype=np.float32)  
roberts_y = np.array([[0, 1], [-1, 0]], dtype=np.float32) 
                     
blurred = blurred.astype(np.float32)  
gradient_x = cv2.filter2D(blurred, -1, roberts_x) 
gradient_y = cv2.filter2D(blurred, -1, roberts_y)  

gradient_x = gradient_x.astype(np.float32)  
gradient_y = gradient_y.astype(np.float32)  

gradient_magnitude = cv2.magnitude(gradient_x, gradient_y) 
gradient_magnitude = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX )  
gradient_magnitude = np.uint8(gradient_magnitude ) 

edges = cv2.Canny(gradient_magnitude, 50, 100)  

plt.figure(figsize=(12, 6))  
plt.subplot(1, 3, 1) 
plt.imshow(image, cmap='gray') 
plt.title("Original Image") 
plt.axis("off") 

plt.subplot(1, 3, 2)  
plt.imshow(gradient_magnitude, cmap='gray')  
plt.title("Gradient Magnitude (Roberts)")  
plt.axis("off")  

plt.subplot(1, 3, 3) 
plt.imshow(edges, cmap='gray')  
plt.title("Canny Edge Detection (Roberts)")  
plt.axis("off")  
plt.show()

# %%
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if image is None:  
    raise FileNotFoundError(f"Image not found: {image_path}")  

blurred = cv2.GaussianBlur(image, (5, 5), 1.4)  
prewitt_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]], dtype=np.float32)  
prewitt_y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]], dtype=np.float32)  

blurred = blurred.astype(np.float32)

gradient_x = cv2.filter2D(blurred, -1, prewitt_x)  
gradient_y = cv2.filter2D(blurred, -1, prewitt_y)  

gradient_x = gradient_x.astype(np.float32)  
gradient_y = gradient_y.astype(np.float32)  

gradient_magnitude = cv2.magnitude(gradient_x, gradient_y)  
gradient_magnitude = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX) 
gradient_magnitude = np.uint8(gradient_magnitude)  

edges = cv2.Canny(gradient_magnitude, 50, 100)  

plt.figure(figsize=(12, 6))  
plt.subplot(1, 3, 1)  
plt.imshow(image, cmap='gray')  
plt.title("Original Image")  
plt.axis("off") 

plt.subplot(1, 3, 2)  
plt.imshow(gradient_magnitude, cmap='gray')  
plt.title("Gradient Magnitude (Prewitt)") 
plt.axis("off")  
plt.subplot(1, 3, 3) 

  
plt.imshow(edges, cmap='gray')  
plt.title("Canny Edge Detection (Prewitt)")  
plt.axis("off") 
plt.show()

# %%
image_path = "C:/Users/DELL/OneDrive/Desktop/Afraa/Images/lena.png" 
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) 

if image is None: 
    raise FileNotFoundError(f"Image not found: {image_path}")  
    
blurred = cv2.GaussianBlur(image, (5, 5), 1.4)
roberts_x = np.array([[1, 0], [0, -1]], dtype=np.float32)  
roberts_y = np.array([[0, 1], [-1, 0]], dtype=np.float32) 
                     
blurred = blurred.astype(np.float32)  
gradient_x = cv2.filter2D(blurred, -1, roberts_x) 
gradient_y = cv2.filter2D(blurred, -1, roberts_y)  

gradient_x = gradient_x.astype(np.float32)  
gradient_y = gradient_y.astype(np.float32)  

gradient_magnitude = cv2.magnitude(gradient_x, gradient_y) 
gradient_magnitude = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX )  
gradient_magnitude = np.uint8(gradient_magnitude ) 

edges = cv2.Canny(gradient_magnitude, 50, 100)  

plt.figure(figsize=(12, 6))  
plt.subplot(1, 3, 1) 
plt.imshow(image, cmap='gray') 
plt.title("Original Image") 
plt.axis("off") 

plt.subplot(1, 3, 2)  
plt.imshow(gradient_magnitude, cmap='gray')  
plt.title("Gradient Magnitude (Roberts)")  
plt.axis("off")  

plt.subplot(1, 3, 3) 
plt.imshow(edges, cmap='gray')  
plt.title("Canny Edge Detection (Roberts)")  
plt.axis("off")  
plt.show()

# %%
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if image is None:  
    raise FileNotFoundError(f"Image not found: {image_path}")  

blurred = cv2.GaussianBlur(image, (5, 5), 1.4)  
prewitt_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]], dtype=np.float32)  
prewitt_y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]], dtype=np.float32)  

blurred = blurred.astype(np.float32)

gradient_x = cv2.filter2D(blurred, -1, prewitt_x)  
gradient_y = cv2.filter2D(blurred, -1, prewitt_y)  

gradient_x = gradient_x.astype(np.float32)  
gradient_y = gradient_y.astype(np.float32)  

gradient_magnitude = cv2.magnitude(gradient_x, gradient_y)  
gradient_magnitude = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX) 
gradient_magnitude = np.uint8(gradient_magnitude)  

edges = cv2.Canny(gradient_magnitude, 50, 100)  

plt.figure(figsize=(12, 6))  
plt.subplot(1, 3, 1)  
plt.imshow(image, cmap='gray')  
plt.title("Original Image")  
plt.axis("off") 

plt.subplot(1, 3, 2)  
plt.imshow(gradient_magnitude, cmap='gray')  
plt.title("Gradient Magnitude (Prewitt)") 
plt.axis("off")  
plt.subplot(1, 3, 3) 

  
plt.imshow(edges, cmap='gray')  
plt.title("Canny Edge Detection (Prewitt)")  
plt.axis("off") 
plt.show()
